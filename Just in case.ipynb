# %%
try: 
  # Si se usa en Colab importando el repositorio
  # !git clone https://github.com/JECaballeroR/EmployeeTurnover.git
  # !pip install -r /content/EmployeeTurnover/requirements.txt
except: 
  # Si se corre local
  # !pip install requirements.txt
# Out:
# Cloning into 'EmployeeTurnover'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 58 (delta 24), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (58/58), done.
# Requirement already satisfied: absl-py==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: alabaster==0.7.12 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 2)) (0.7.12)
# Requirement already satisfied: albumentations==0.1.12 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 3)) (0.1.12)
# Requirement already satisfied: altair==4.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: appdirs==1.4.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: argon2-cffi==20.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 6)) (20.1.0)
# Requirement already satisfied: asgiref==3.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 7)) (3.3.1)
# Requirement already satisfied: astor==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 8)) (0.8.1)
# Requirement already satisfied: astropy==4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 9)) (4.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: async-generator==1.10 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 11)) (1.10)
# Requirement already satisfied: atari-py==0.2.6 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 12)) (0.2.6)
# Requirement already satisfied: atomicwrites==1.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: attrs==20.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 14)) (20.3.0)
# Requirement already satisfied: audioread==2.1.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 15)) (2.1.9)
# Requirement already satisfied: autograd==1.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 16)) (1.3)
# Requirement already satisfied: Babel==2.9.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 17)) (2.9.0)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.6.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 19)) (4.6.3)
# Requirement already satisfied: bleach==3.2.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 20)) (3.2.3)
# Requirement already satisfied: blis==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: bokeh==2.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 22)) (2.1.1)
# Requirement already satisfied: Bottleneck==1.3.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 23)) (1.3.2)
# Requirement already satisfied: branca==0.4.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 24)) (0.4.2)
# Requirement already satisfied: bs4==0.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 25)) (0.0.1)
# Requirement already satisfied: CacheControl==0.12.6 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 26)) (0.12.6)
# Requirement already satisfied: cachetools==4.2.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 27)) (4.2.1)
# Requirement already satisfied: catalogue==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 28)) (1.0.0)
# Requirement already satisfied: certifi==2020.12.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 29)) (2020.12.5)
# Requirement already satisfied: cffi==1.14.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 30)) (1.14.4)
# Requirement already satisfied: chainer==7.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 31)) (7.4.0)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 32)) (3.0.4)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 33)) (7.1.2)
# Requirement already satisfied: cloudpickle==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 34)) (1.3.0)
# Requirement already satisfied: cmake==3.12.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 35)) (3.12.0)
# Requirement already satisfied: cmdstanpy==0.9.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 36)) (0.9.5)
# Requirement already satisfied: colorlover==0.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 37)) (0.3.0)
# Requirement already satisfied: community==1.0.0b1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 38)) (1.0.0b1)
# Requirement already satisfied: contextlib2==0.5.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 39)) (0.5.5)
# Requirement already satisfied: convertdate==2.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 40)) (2.2.0)
# Requirement already satisfied: coverage==3.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 41)) (3.7.1)
# Requirement already satisfied: coveralls==0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 42)) (0.5)
# Requirement already satisfied: crcmod==1.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 43)) (1.7)
# Requirement already satisfied: cufflinks==0.17.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 44)) (0.17.3)
# Requirement already satisfied: cvxopt==1.2.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 45)) (1.2.5)
# Requirement already satisfied: cvxpy==1.0.31 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 46)) (1.0.31)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 47)) (0.10.0)
# Requirement already satisfied: cymem==2.0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 48)) (2.0.5)
# Requirement already satisfied: Cython==0.29.21 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 49)) (0.29.21)
# Requirement already satisfied: daft==0.0.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 50)) (0.0.4)
# Requirement already satisfied: dask==2.12.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 51)) (2.12.0)
# Requirement already satisfied: dataclasses==0.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 52)) (0.8)
# Requirement already satisfied: datascience==0.10.6 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 53)) (0.10.6)
# Requirement already satisfied: debugpy==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 54)) (1.0.0)
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 55)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 56)) (0.6.0)
# Requirement already satisfied: descartes==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 57)) (1.1.0)
# Requirement already satisfied: dill==0.3.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 58)) (0.3.3)
# Requirement already satisfied: distributed==1.25.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 59)) (1.25.3)
# Requirement already satisfied: Django==3.1.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 60)) (3.1.5)
# Requirement already satisfied: dlib==19.18.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 61)) (19.18.0)
# Requirement already satisfied: dm-tree==0.1.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 62)) (0.1.5)
# Requirement already satisfied: docopt==0.6.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 63)) (0.6.2)
# Requirement already satisfied: docutils==0.16 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 64)) (0.16)
# Requirement already satisfied: dopamine-rl==1.0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 65)) (1.0.5)
# Requirement already satisfied: earthengine-api==0.1.238 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 66)) (0.1.238)
# Requirement already satisfied: easydict==1.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 67)) (1.9)
# Requirement already satisfied: ecos==2.0.7.post1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 68)) (2.0.7.post1)
# Requirement already satisfied: editdistance==0.5.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 69)) (0.5.3)
# Requirement already satisfied: en-core-web-sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 70)) (2.2.5)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 71)) (0.3)
# Requirement already satisfied: ephem==3.7.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 72)) (3.7.7.1)
# Requirement already satisfied: et-xmlfile==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 73)) (1.0.1)
# Requirement already satisfied: fa2==0.3.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 74)) (0.3.5)
# Requirement already satisfied: fancyimpute==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 75)) (0.4.3)
# Requirement already satisfied: fastai==1.0.61 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 76)) (1.0.61)
# Requirement already satisfied: fastdtw==0.3.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 77)) (0.3.4)
# Requirement already satisfied: fastprogress==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 78)) (1.0.0)
# Requirement already satisfied: fastrlock==0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 79)) (0.5)
# Requirement already satisfied: fbprophet==0.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 80)) (0.7.1)
# Requirement already satisfied: feather-format==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 81)) (0.4.1)
# Requirement already satisfied: filelock==3.0.12 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 82)) (3.0.12)
# Requirement already satisfied: firebase-admin==4.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 83)) (4.4.0)
# Requirement already satisfied: fix-yahoo-finance==0.0.22 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 84)) (0.0.22)
# Requirement already satisfied: Flask==1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 85)) (1.1.2)
# Requirement already satisfied: flatbuffers==1.12 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 86)) (1.12)
# Requirement already satisfied: folium==0.8.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 87)) (0.8.3)
# Requirement already satisfied: future==0.16.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 88)) (0.16.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 89)) (0.3.3)
# Requirement already satisfied: GDAL==2.2.2 in /usr/lib/python3/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 90)) (2.2.2)
# Requirement already satisfied: gdown==3.6.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 91)) (3.6.4)
# Requirement already satisfied: gensim==3.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 92)) (3.6.0)
# Requirement already satisfied: geographiclib==1.50 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 93)) (1.50)
# Requirement already satisfied: geopy==1.17.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 94)) (1.17.0)
# Requirement already satisfied: gin-config==0.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 95)) (0.4.0)
# Requirement already satisfied: glob2==0.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 96)) (0.7)
# Requirement already satisfied: google==2.0.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 97)) (2.0.3)
# Requirement already satisfied: google-api-core==1.16.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 98)) (1.16.0)
# Requirement already satisfied: google-api-python-client==1.7.12 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 99)) (1.7.12)
# Requirement already satisfied: google-auth==1.17.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 100)) (1.17.2)
# Requirement already satisfied: google-auth-httplib2==0.0.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 101)) (0.0.4)
# Requirement already satisfied: google-auth-oauthlib==0.4.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 102)) (0.4.2)
# Requirement already satisfied: google-cloud-bigquery==1.21.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 103)) (1.21.0)
# Requirement already satisfied: google-cloud-bigquery-storage==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 104)) (1.1.0)
# Requirement already satisfied: google-cloud-core==1.0.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 105)) (1.0.3)
# Requirement already satisfied: google-cloud-datastore==1.8.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 106)) (1.8.0)
# Requirement already satisfied: google-cloud-firestore==1.7.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 107)) (1.7.0)
# Requirement already satisfied: google-cloud-language==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 108)) (1.2.0)
# Requirement already satisfied: google-cloud-storage==1.18.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 109)) (1.18.1)
# Requirement already satisfied: google-cloud-translate==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 110)) (1.5.0)
# Requirement already satisfied: google-colab==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 111)) (1.0.0)
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 112)) (0.2.0)
# Requirement already satisfied: google-resumable-media==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 113)) (0.4.1)
# Requirement already satisfied: googleapis-common-protos==1.52.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 114)) (1.52.0)
# Requirement already satisfied: googledrivedownloader==0.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 115)) (0.4)
# Requirement already satisfied: graphviz==0.10.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 116)) (0.10.1)
# Requirement already satisfied: grpcio==1.32.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 117)) (1.32.0)
# Requirement already satisfied: gspread==3.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 118)) (3.0.1)
# Requirement already satisfied: gspread-dataframe==3.0.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 119)) (3.0.8)
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 120)) (0.17.3)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 121)) (2.10.0)
# Requirement already satisfied: HeapDict==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 122)) (1.0.1)
# Requirement already satisfied: holidays==0.10.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 123)) (0.10.4)
# Requirement already satisfied: holoviews==1.13.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 124)) (1.13.5)
# Requirement already satisfied: html5lib==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 125)) (1.0.1)
# Requirement already satisfied: httpimport==0.5.18 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 126)) (0.5.18)
# Requirement already satisfied: httplib2==0.17.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 127)) (0.17.4)
# Requirement already satisfied: httplib2shim==0.0.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 128)) (0.0.3)
# Requirement already satisfied: humanize==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 129)) (0.5.1)
# Requirement already satisfied: hyperopt==0.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 130)) (0.1.2)
# Requirement already satisfied: ideep4py==2.0.0.post3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 131)) (2.0.0.post3)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 132)) (2.10)
# Requirement already satisfied: image==1.5.33 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 133)) (1.5.33)
# Requirement already satisfied: imageio==2.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 134)) (2.4.1)
# Requirement already satisfied: imagesize==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 135)) (1.2.0)
# Requirement already satisfied: imbalanced-learn==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 136)) (0.4.3)
# Requirement already satisfied: imblearn==0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 137)) (0.0)
# Requirement already satisfied: imgaug==0.2.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 138)) (0.2.9)
# Requirement already satisfied: importlib-metadata==3.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 139)) (3.4.0)
# Requirement already satisfied: importlib-resources==5.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 140)) (5.1.0)
# Requirement already satisfied: imutils==0.5.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 141)) (0.5.4)
# Requirement already satisfied: inflect==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 142)) (2.1.0)
# Requirement already satisfied: iniconfig==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 143)) (1.1.1)
# Requirement already satisfied: intel-openmp==2021.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 144)) (2021.1.2)
# Requirement already satisfied: intervaltree==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 145)) (2.1.0)
# Requirement already satisfied: ipykernel==4.10.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 146)) (4.10.1)
# Requirement already satisfied: ipython==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 147)) (5.5.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 148)) (0.2.0)
# Requirement already satisfied: ipython-sql==0.3.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 149)) (0.3.9)
# Requirement already satisfied: ipywidgets==7.6.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 150)) (7.6.3)
# Requirement already satisfied: itsdangerous==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 151)) (1.1.0)
# Requirement already satisfied: jax==0.2.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 152)) (0.2.8)
# Requirement already satisfied: jaxlib==0.1.59+cuda101 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 153)) (0.1.59+cuda101)
# Requirement already satisfied: jdcal==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 154)) (1.4.1)
# Requirement already satisfied: jedi==0.18.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 155)) (0.18.0)
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 156)) (0.42.1)
# Requirement already satisfied: Jinja2==2.11.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 157)) (2.11.2)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 158)) (1.0.0)
# Requirement already satisfied: jpeg4py==0.1.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 159)) (0.1.4)
# Requirement already satisfied: jsonschema==2.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 160)) (2.6.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 161)) (1.0.0)
# Requirement already satisfied: jupyter-client==5.3.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 162)) (5.3.5)
# Requirement already satisfied: jupyter-console==5.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 163)) (5.2.0)
# Requirement already satisfied: jupyter-core==4.7.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 164)) (4.7.0)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 165)) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 166)) (1.0.0)
# Requirement already satisfied: kaggle==1.5.10 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 167)) (1.5.10)
# Requirement already satisfied: kapre==0.1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 168)) (0.1.3.1)
# Requirement already satisfied: Keras==2.4.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 169)) (2.4.3)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 170)) (1.1.2)
# Requirement already satisfied: keras-vis==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 171)) (0.4.1)
# Requirement already satisfied: kiwisolver==1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 172)) (1.3.1)
# Requirement already satisfied: knnimpute==0.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 173)) (0.1.0)
# Requirement already satisfied: korean-lunar-calendar==0.2.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 174)) (0.2.1)
# Requirement already satisfied: librosa==0.8.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 175)) (0.8.0)
# Requirement already satisfied: lightgbm==2.2.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 176)) (2.2.3)
# Requirement already satisfied: llvmlite==0.34.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 177)) (0.34.0)
# Requirement already satisfied: lmdb==0.99 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 178)) (0.99)
# Requirement already satisfied: lucid==0.3.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 179)) (0.3.8)
# Requirement already satisfied: LunarCalendar==0.0.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 180)) (0.0.9)
# Requirement already satisfied: lxml==4.2.6 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 181)) (4.2.6)
# Requirement already satisfied: Markdown==3.3.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 182)) (3.3.3)
# Requirement already satisfied: MarkupSafe==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 183)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 184)) (3.2.2)
# Requirement already satisfied: matplotlib-venn==0.11.6 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 185)) (0.11.6)
# Requirement already satisfied: missingno==0.4.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 186)) (0.4.2)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 187)) (0.8.4)
# Requirement already satisfied: mizani==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 188)) (0.6.0)
# Requirement already satisfied: mkl==2019.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 189)) (2019.0)
# Requirement already satisfied: mlxtend==0.14.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 190)) (0.14.0)
# Requirement already satisfied: more-itertools==8.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 191)) (8.6.0)
# Requirement already satisfied: moviepy==0.2.3.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 192)) (0.2.3.5)
# Requirement already satisfied: mpmath==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 193)) (1.1.0)
# Requirement already satisfied: msgpack==1.0.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 194)) (1.0.2)
# Requirement already satisfied: multiprocess==0.70.11.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 195)) (0.70.11.1)
# Requirement already satisfied: multitasking==0.0.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 196)) (0.0.9)
# Requirement already satisfied: murmurhash==1.0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 197)) (1.0.5)
# Requirement already satisfied: music21==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 198)) (5.5.0)
# Requirement already satisfied: natsort==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 199)) (5.5.0)
# Requirement already satisfied: nbclient==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 200)) (0.5.1)
# Requirement already satisfied: nbconvert==5.6.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 201)) (5.6.1)
# Requirement already satisfied: nbformat==5.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 202)) (5.1.2)
# Requirement already satisfied: nest-asyncio==1.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 203)) (1.5.1)
# Requirement already satisfied: networkx==2.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 204)) (2.5)
# Requirement already satisfied: nibabel==3.0.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 205)) (3.0.2)
# Collecting nltk==3.4.5
#   Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip (1.5MB)
#      |████████████████████████████████| 1.5MB 4.1MB/s
# Requirement already satisfied: notebook==5.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 207)) (5.3.1)
# Requirement already satisfied: np-utils==0.5.12.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 208)) (0.5.12.1)
# Requirement already satisfied: numba==0.51.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 209)) (0.51.2)
# Requirement already satisfied: numexpr==2.7.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 210)) (2.7.2)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 211)) (1.19.5)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 212)) (7.352.0)
# Requirement already satisfied: oauth2client==4.1.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 213)) (4.1.3)
# Requirement already satisfied: oauthlib==3.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 214)) (3.1.0)
# Requirement already satisfied: okgrade==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 215)) (0.4.3)
# Requirement already satisfied: opencv-contrib-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 216)) (4.1.2.30)
# Requirement already satisfied: opencv-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 217)) (4.1.2.30)
# Requirement already satisfied: openpyxl==2.5.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 218)) (2.5.9)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 219)) (3.3.0)
# Requirement already satisfied: osqp==0.6.2.post0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 220)) (0.6.2.post0)
# Requirement already satisfied: packaging==20.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 221)) (20.8)
# Requirement already satisfied: palettable==3.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 222)) (3.3.0)
# Requirement already satisfied: pandas==1.1.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 223)) (1.1.5)
# Requirement already satisfied: pandas-datareader==0.9.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 224)) (0.9.0)
# Requirement already satisfied: pandas-gbq==0.13.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 225)) (0.13.3)
# Requirement already satisfied: pandas-profiling==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 226)) (1.4.1)
# Requirement already satisfied: pandocfilters==1.4.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 227)) (1.4.3)
# Requirement already satisfied: panel==0.9.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 228)) (0.9.7)
# Requirement already satisfied: param==1.10.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 229)) (1.10.1)
# Requirement already satisfied: parso==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 230)) (0.8.1)
# Requirement already satisfied: pathlib==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 231)) (1.0.1)
# Requirement already satisfied: patsy==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 232)) (0.5.1)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 233)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 234)) (0.7.5)
# Requirement already satisfied: Pillow==7.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 235)) (7.0.0)
# Requirement already satisfied: pip-tools==4.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 236)) (4.5.1)
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 237)) (1.1.3)
# Requirement already satisfied: plotly==4.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 238)) (4.4.1)
# Requirement already satisfied: plotnine==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 239)) (0.6.0)
# Requirement already satisfied: pluggy==0.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 240)) (0.7.1)
# Requirement already satisfied: pooch==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 241)) (1.3.0)
# Requirement already satisfied: portpicker==1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 242)) (1.3.1)
# Requirement already satisfied: ppscore==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 243)) (1.2.0)
# Requirement already satisfied: prefetch-generator==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 244)) (1.0.1)
# Requirement already satisfied: preshed==3.0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 245)) (3.0.5)
# Requirement already satisfied: prettytable==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 246)) (2.0.0)
# Requirement already satisfied: progressbar2==3.38.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 247)) (3.38.0)
# Requirement already satisfied: prometheus-client==0.9.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 248)) (0.9.0)
# Requirement already satisfied: promise==2.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 249)) (2.3)
# Requirement already satisfied: prompt-toolkit==1.0.18 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 250)) (1.0.18)
# Requirement already satisfied: protobuf==3.12.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 251)) (3.12.4)
# Requirement already satisfied: psutil==5.4.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 252)) (5.4.8)
# Requirement already satisfied: psycopg2==2.7.6.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 253)) (2.7.6.1)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 254)) (0.7.0)
# Requirement already satisfied: py==1.10.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 255)) (1.10.0)
# Requirement already satisfied: pyarrow==0.14.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 256)) (0.14.1)
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 257)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 258)) (0.2.8)
# Requirement already satisfied: pycocotools==2.0.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 259)) (2.0.2)
# Requirement already satisfied: pycparser==2.20 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 260)) (2.20)
# Requirement already satisfied: pyct==0.4.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 261)) (0.4.8)
# Requirement already satisfied: pydata-google-auth==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 262)) (1.1.0)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 263)) (1.3.0)
# Requirement already satisfied: pydot-ng==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 264)) (2.0.0)
# Requirement already satisfied: pydotplus==2.0.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 265)) (2.0.2)
# Requirement already satisfied: PyDrive==1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 266)) (1.3.1)
# Requirement already satisfied: pyemd==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 267)) (0.5.1)
# Requirement already satisfied: pyglet==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 268)) (1.5.0)
# Requirement already satisfied: Pygments==2.6.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 269)) (2.6.1)
# Requirement already satisfied: pygobject==3.26.1 in /usr/lib/python3/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 270)) (3.26.1)
# Requirement already satisfied: pymc3==3.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 271)) (3.7)
# Requirement already satisfied: PyMeeus==0.3.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 272)) (0.3.7)
# Requirement already satisfied: pymongo==3.11.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 273)) (3.11.2)
# Requirement already satisfied: pymystem3==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 274)) (0.2.0)
# Requirement already satisfied: pynndescent==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 275)) (0.5.1)
# Requirement already satisfied: PyOpenGL==3.1.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 276)) (3.1.5)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 277)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.17.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 278)) (0.17.3)
# Requirement already satisfied: pysndfile==1.3.8 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 279)) (1.3.8)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 280)) (1.7.1)
# Requirement already satisfied: pystan==2.19.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 281)) (2.19.1.1)
# Requirement already satisfied: pytest==3.6.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 282)) (3.6.4)
# Requirement already satisfied: python-apt==1.6.5+ubuntu0.5 in /usr/lib/python3/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 283)) (1.6.5+ubuntu0.5)
# Requirement already satisfied: python-chess==0.23.11 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 284)) (0.23.11)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 285)) (2.8.1)
# Requirement already satisfied: python-louvain==0.15 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 286)) (0.15)
# Requirement already satisfied: python-slugify==4.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 287)) (4.0.1)
# Requirement already satisfied: python-utils==2.5.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 288)) (2.5.5)
# Requirement already satisfied: pytz==2018.9 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 289)) (2018.9)
# Requirement already satisfied: pyviz-comms==2.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 290)) (2.0.1)
# Requirement already satisfied: PyWavelets==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 291)) (1.1.1)
# Collecting PyYAML==4.2b1
#   Downloading https://files.pythonhosted.org/packages/bd/da/0a49c1a31c60634b93fd1376b3b7966c4f81f2da8263f389cad5b6bbd6e8/PyYAML-4.2b1.tar.gz (263kB)
#      |████████████████████████████████| 266kB 13.5MB/s
# ...
# Requirement already satisfied: regex==2019.12.20 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 297)) (2019.12.20)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 298)) (2.23.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 299)) (1.3.0)
# Requirement already satisfied: resampy==0.2.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 300)) (0.2.2)
# Requirement already satisfied: retrying==1.3.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 301)) (1.3.3)
# Requirement already satisfied: rpy2==3.2.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 302)) (3.2.7)
# Requirement already satisfied: rsa==4.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 303)) (4.7)
# Requirement already satisfied: scikit-image==0.16.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 304)) (0.16.2)
# Requirement already satisfied: scikit-learn==0.22.2.post1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 305)) (0.22.2.post1)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 306)) (1.4.1)
# Requirement already satisfied: screen-resolution-extra==0.0.0 in /usr/lib/python3/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 307)) (0.0.0)
# Requirement already satisfied: scs==2.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 308)) (2.1.2)
# Requirement already satisfied: seaborn==0.11.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 309)) (0.11.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 310)) (1.5.0)
# Requirement already satisfied: setuptools-git==1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 311)) (1.2)
# Requirement already satisfied: Shapely==1.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 312)) (1.7.1)
# Requirement already satisfied: simplegeneric==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 313)) (0.8.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 314)) (1.15.0)
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 315)) (0.0)
# Requirement already satisfied: sklearn-pandas==1.8.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 316)) (1.8.0)
# Requirement already satisfied: smart-open==4.1.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 317)) (4.1.2)
# Requirement already satisfied: snowballstemmer==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 318)) (2.1.0)
# Requirement already satisfied: sortedcontainers==2.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 319)) (2.3.0)
# Requirement already satisfied: SoundFile==0.10.3.post1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 320)) (0.10.3.post1)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 321)) (2.2.4)
# Requirement already satisfied: Sphinx==1.8.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 322)) (1.8.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 323)) (1.1.4)
# Requirement already satisfied: sphinxcontrib-websupport==1.2.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 324)) (1.2.4)
# Requirement already satisfied: SQLAlchemy==1.3.22 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 325)) (1.3.22)
# Requirement already satisfied: sqlparse==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 326)) (0.4.1)
# Requirement already satisfied: srsly==1.0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 327)) (1.0.5)
# Requirement already satisfied: statsmodels==0.10.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 328)) (0.10.2)
# Requirement already satisfied: sympy==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 329)) (1.1.1)
# Requirement already satisfied: tables==3.4.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 330)) (3.4.4)
# Requirement already satisfied: tabulate==0.8.7 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 331)) (0.8.7)
# Requirement already satisfied: tblib==1.7.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 332)) (1.7.0)
# Requirement already satisfied: tensorboard==2.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 333)) (2.4.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 334)) (1.8.0)
# Requirement already satisfied: tensorboardcolab==0.0.22 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 335)) (0.0.22)
# Requirement already satisfied: tensorflow==2.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 336)) (2.4.1)
# Requirement already satisfied: tensorflow-addons==0.8.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 337)) (0.8.3)
# Requirement already satisfied: tensorflow-datasets==4.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 338)) (4.0.1)
# Requirement already satisfied: tensorflow-estimator==2.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 339)) (2.4.0)
# Requirement already satisfied: tensorflow-gcs-config==2.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 340)) (2.4.0)
# Requirement already satisfied: tensorflow-hub==0.11.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 341)) (0.11.0)
# Requirement already satisfied: tensorflow-metadata==0.27.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 342)) (0.27.0)
# Requirement already satisfied: tensorflow-privacy==0.2.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 343)) (0.2.2)
# Requirement already satisfied: tensorflow-probability==0.12.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 344)) (0.12.1)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 345)) (1.1.0)
# Requirement already satisfied: terminado==0.9.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 346)) (0.9.2)
# Requirement already satisfied: testpath==0.4.4 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 347)) (0.4.4)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 348)) (1.3)
# Requirement already satisfied: textblob==0.15.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 349)) (0.15.3)
# Requirement already satisfied: textgenrnn==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 350)) (1.4.1)
# Requirement already satisfied: Theano==1.0.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 351)) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 352)) (7.4.0)
# Requirement already satisfied: tifffile==2020.9.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 353)) (2020.9.3)
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 354)) (0.10.2)
# Requirement already satisfied: toolz==0.11.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 355)) (0.11.1)
# Requirement already satisfied: torch==1.7.0+cu101 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 356)) (1.7.0+cu101)
# Requirement already satisfied: torchsummary==1.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 357)) (1.5.1)
# Requirement already satisfied: torchtext==0.3.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 358)) (0.3.1)
# Requirement already satisfied: torchvision==0.8.1+cu101 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 359)) (0.8.1+cu101)
# Requirement already satisfied: tornado==5.1.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 360)) (5.1.1)
# Requirement already satisfied: tqdm==4.41.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 361)) (4.41.1)
# Requirement already satisfied: traitlets==4.3.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 362)) (4.3.3)
# Requirement already satisfied: tweepy==3.6.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 363)) (3.6.0)
# Requirement already satisfied: typeguard==2.7.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 364)) (2.7.1)
# Requirement already satisfied: typing-extensions==3.7.4.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 365)) (3.7.4.3)
# Requirement already satisfied: tzlocal==1.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 366)) (1.5.1)
# Requirement already satisfied: umap-learn==0.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 367)) (0.5.0)
# Requirement already satisfied: uritemplate==3.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 368)) (3.0.1)
# Requirement already satisfied: urllib3==1.24.3 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 369)) (1.24.3)
# Requirement already satisfied: vega-datasets==0.9.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 370)) (0.9.0)
# Requirement already satisfied: wasabi==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 371)) (0.8.1)
# Requirement already satisfied: wcwidth==0.2.5 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 372)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 373)) (0.5.1)
# Requirement already satisfied: Werkzeug==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 374)) (1.0.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 375)) (3.5.1)
# Requirement already satisfied: wordcloud==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 376)) (1.5.0)
# Requirement already satisfied: wrapt==1.12.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 377)) (1.12.1)
# Requirement already satisfied: xarray==0.15.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 378)) (0.15.1)
# Requirement already satisfied: xgboost==0.90 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 379)) (0.90)
# Requirement already satisfied: xkit==0.0.0 in /usr/lib/python3/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 380)) (0.0.0)
# Requirement already satisfied: xlrd==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 381)) (1.1.0)
# Requirement already satisfied: xlwt==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 382)) (1.3.0)
# Requirement already satisfied: yellowbrick==0.9.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 383)) (0.9.1)
# Requirement already satisfied: zict==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 384)) (2.0.0)
# Requirement already satisfied: zipp==3.4.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/EmployeeTurnover/requirements.txt (line 385)) (3.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse==1.6.3->-r /content/EmployeeTurnover/requirements.txt (line 10)) (0.36.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer==7.4.0->-r /content/EmployeeTurnover/requirements.txt (line 31)) (51.3.3)
# Building wheels for collected packages: nltk, PyYAML
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449907 sha256=e7e9873e1fe7e65c9d09d6609af3807b0208cc1a5832763dde50539e8a15f99c
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-4.2b1-cp36-cp36m-linux_x86_64.whl size=43427 sha256=38f740ad0e18ac8633ec0dd1e96c32209f301f19aea47e374bb1f5b8fa08bb58
#   Stored in directory: /root/.cache/pip/wheels/07/5c/af/6d232d1db016150174e48d140cc4665103eab778024ea5a517
# Successfully built nltk PyYAML
# Installing collected packages: nltk, PyYAML
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-4.2b1 nltk-3.4.5

# %%
import ppscore as pps
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.pipeline import make_pipeline
from sklearn.model_selection import  GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import (f1_score, roc_auc_score, precision_recall_curve, 
                            roc_curve, confusion_matrix, classification_report, 
                            accuracy_score)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.utils import resample
from sklearn.neighbors import KNeighborsClassifier
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import joblib

from warnings import filterwarnings

filterwarnings("ignore")

# %% [markdown]
# # Employee turnover: Predecir la probablidad de que un empleado renuncie usando Machine Learning
#
# ¿Cómo podemos  retener nuestro talento?
#
# Es una pregunta que toda organización del mundo debería hacerse. El talento es el insumo de mayor valor para cada organización, dado que es el mayor generador de valor: No importan los recursos si no hay gente habilidosa, motivada detrás de ellos.
#
# Para poder retener el talento, es necesario entender la razón de la salida de los empleados: si se sabe quién está en riesgo de abandonar la organización, se pueden tomar medidas preventivas.
#
# En el presente Jupyter notebook, se ilustrará el proceso para la obtenición de un modelo preliminar de Machine Learning para la predicción de la probabilidad de que un empleado abandone una organización. Para esto, se utilizará un dataser de Kaggle que contiene una serie de features asociadas a los empleados, además de una variables binaria que determina si el empleado abandonó o no la organización.
#
# A grandes rasgos, los pasos que se seguirán serán:
# 1. **Carga y validación de los datos:** Se verifica que los datos a usar sean integrales, que no haya faltantes, que sus valores sean coherentes con la realidad.
# 2. **Análisis Exploratorio:** Se exploran los datos para detectar posibles interacciones de interés. En el caso de dataset con muchos features, se usaría como base para empezar con los modelos.
# 3. **Preparación de los datos:** Se realiza preparación y limpieza de datos para los modelos (Normalizar, Estandarizar, Upsampling/Downsampling, generación de datos sintéticos, rellenado de faltantes, entre otras posibilidades). Adicionalmente, se separa un fragmento de los datos para posteriormente probar los modelos en ellos.
# 4. **Modelado inicial:** Se prueba con algunos modelos básicos.
# 5. **Optimización de hiper parámetros**: Se aproxima a la mejor combinación de hiper parámetros del modelo seleccionado para los datos que se tienen.
# 6. **Selección del mejor modelo** Con los datos separados en el punto 3, se prueban todos los modelos y se elige aquel con un mejor desempeño.
#
# # Carga y validación de los datos
# ##Carga y exploración básica
#
#
# Los features del dataset son:
# * **satisfaction_level**: Nivel de Satisfacción, de 0 a 1 (Flotante).
# * **last_evaluationTime**: Años desde la última evaluación de desempeño (Flotante)
# * **number_project**:Cantidad de proyectos terminados durante la vinculación laboral (Entera)
# * **average_montly_hours**: Horas promedio mensuales trabajadas (Entera)
# * **time_spend_company**: Años de vinculación en la compañía (Entera)
# * **Work_accident**: Si el empleado tuvo o no Accidente de trabajo (Binaria)
# * **left**: Si el empleado dejo o no el trabajo (Variable Respuesta) (Binaria)
# * **promotion_last_5years**: Si el empleado tuvo o no un ascenso en los últimos 5 años (Binaria).
# * **sales**: Departamento al que el empleado estuvo vinculado (Categórica).
# * **salary**: Nivel relativo del salario (low, medium, high) (Categórica)
#
#
#
# Se cargan los datos y se validan ciertos elementos, a saber:
#
# *   Que no haya datos faltantes
# *   Que todos los datos sean coherentes con las variables
# *   Que la variable respuesta este balanceada
#
# Después de estas validaciones iniciales, se modifican los nombres de las variables para su interpretabilidad y se realiza un Análisis de Datos Exploratorio para conocer mejor el dataset.

# %%
#Se carga y presentan los datos
try: 
  # Si se usa en Colab importando el repositorio
  file_path="/content/EmployeeTurnover/data/HR_comma_sep.csv"
except: 
  # Si se corre local
  file_path="/data/HR_comma_sep.csv"
df=pd.read_csv(file_path)
df
# Out:
#        satisfaction_level  last_evaluation  ...    sales  salary
# 0                    0.38             0.53  ...    sales     low
# 1                    0.80             0.86  ...    sales  medium
# 2                    0.11             0.88  ...    sales  medium
# 3                    0.72             0.87  ...    sales     low
# 4                    0.37             0.52  ...    sales     low
# ...                   ...              ...  ...      ...     ...
# 14994                0.40             0.57  ...  support     low
# 14995                0.37             0.48  ...  support     low
# 14996                0.37             0.53  ...  support     low
# 14997                0.11             0.96  ...  support     low
# 14998                0.37             0.52  ...  support     low
#
# [14999 rows x 10 columns]

# %%
#Verificación de datos nulos en el dataset
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
#Para variables categoricas y binarias, verificación de que no hayan elementos mal escritos o similar.
#Para esto, se imprimen los valores únicos de cada variable
variables_bin_cat=[ 'Work_accident', "left", "promotion_last_5years", "sales", "salary"]
[ (i, df[i].unique()) for i in variables_bin_cat]
# Out:
# [('Work_accident', array([0, 1])),
#  ('left', array([1, 0])),
#  ('promotion_last_5years', array([0, 1])),
#  ('sales',
#   array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#          'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)),
#  ('salary', array(['low', 'medium', 'high'], dtype=object))]

# %%
#Para la verificación de variables númericas continuas, se usa DataFrame.describe() para validar el rango de los datos
df.describe()
# Out:
#        satisfaction_level  last_evaluation  ...          left  promotion_last_5years
# count        14999.000000     14999.000000  ...  14999.000000           14999.000000
# mean             0.612834         0.716102  ...      0.238083               0.021268
# std              0.248631         0.171169  ...      0.425924               0.144281
# min              0.090000         0.360000  ...      0.000000               0.000000
# 25%              0.440000         0.560000  ...      0.000000               0.000000
# 50%              0.640000         0.720000  ...      0.000000               0.000000
# 75%              0.820000         0.870000  ...      0.000000               0.000000
# max              1.000000         1.000000  ...      1.000000               1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# De este dataframe se puede observar que:
# 1.   Las evaluaciones de desempeño se realizan juiciosamente de manera anual, dado que el máximo valor es 1 (eso, o quizá son más bien el nivel de desempeño en la última evaluación de desempeño)
# 2.   Existen empleados que trabajan más de 10 horas al día en promedio (máximo de 310 horas al mes/30 días al mes= 10.33 horas al día). A priori, parece una posible causa de abandono.
# 3. Se observa que la mayoría de empleados (al menos el 75%) no han abandonado a la compañía, recibido un ascenso en los últimos 5 años o tenido un accidente de trabajo. Esto sugiere que el dataset está no balanceado
# 4. Igualmente, al menos el 75% de los empleados a trabajado con la compañía menos de 5 años, por lo que el punto 3 parece indicar que no hay muchos ascensos en la companía (otro posible factor de abandono)
# 5. En general, parece no existir problemas con los datos.

# %%
# Se verifica si la variable respuesta se encuentra balanceada en el dataset, mostrando el conteo de la misma
df.groupby("left")['sales'].count().plot(kind='bar')

# %%
# Se renombra "sales" como "department", "salary" como "salary_level", "left" como "employee_left"
# Esto es para dar nombres más interpretables de las variables
df=df.rename(columns = {'sales':'department', 'salary': 'salary_level', 'left':'employee_left'})

# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
#
# Se revisará a mayor profundidad los datos para detectar ciertas interacciones y guiar la futura interpretación de los modelos.
#
# Para ello, se revisarán interacciones, agrupaciones y visualizaciones de los datos, y se generarán ideas del algunas interacciones interesantes que se detecten.
#
# 1. Observar si, al agrupar los datos por alguna variable, se observa que alguna otra tiene un nivel diferente (por ejemplo, si se ve un cambio en los niveles de motivación entre los diferentes niveles de salario).
# 2. Generar algunos heatmaps para apoyar las posibles tendencias que se vean (por ejemplo, detectar los departamentos de mayor rotación de personal)
# 3. Generar visualizaciones de apoyo para encaminar el primer modelo (elegir features)

# %%
df.groupby('employee_left').mean()
# Out:
#                satisfaction_level  ...  promotion_last_5years
# employee_left                      ...
# 0                        0.666810  ...               0.026251
# 1                        0.440098  ...               0.005321
#
# [2 rows x 7 columns]

# %%
df.groupby(['employee_left','salary_level']).mean()
# Out:
#                             satisfaction_level  ...  promotion_last_5years
# employee_left salary_level                      ...
# 0             high                    0.651879  ...               0.062338
#               low                     0.668103  ...               0.010109
#               medium                  0.668875  ...               0.034315
# 1             high                    0.434512  ...               0.000000
#               low                     0.441248  ...               0.006446
#               medium                  0.438550  ...               0.003797
#
# [6 rows x 7 columns]

# %% [markdown]
# Se observa que el nivel de satisfacción es mayor para los empleados que se mantienen en la empresa. Los que aun trabajan han tenido más ascensos y accidentes de trabajo.
#
# Los empleados de alto salario que abandonaron la empresa no tuvieron accidentes laborales o ascensos, siendo quizá este último una causa de su deserción.

# %%
df.groupby('salary_level').mean()
# Out:
#               satisfaction_level  ...  promotion_last_5years
# salary_level                      ...
# high                    0.637470  ...               0.058205
# low                     0.600753  ...               0.009021
# medium                  0.621817  ...               0.028079
#
# [3 rows x 8 columns]

# %% [markdown]
# Se observa que el mayor salario parece inducir a menos probablidad de ascensos y a una menor tasa de abandono. Los demas factores lucen relativamente similares.

# %%
df.groupby('department').mean()
# Out:
#              satisfaction_level  ...  promotion_last_5years
# department                       ...
# IT                     0.618142  ...               0.002445
# RandD                  0.619822  ...               0.034307
# accounting             0.582151  ...               0.018253
# hr                     0.598809  ...               0.020298
# management             0.621349  ...               0.109524
# marketing              0.618601  ...               0.050117
# product_mng            0.619634  ...               0.000000
# sales                  0.614447  ...               0.024155
# support                0.618300  ...               0.008973
# technical              0.607897  ...               0.010294
#
# [10 rows x 8 columns]

# %% [markdown]
# Parece ser que el departamento en que un empleado trabaja afecta principalmente sus posibilidades de ascenso. La tasa de salida varía por deparamento también, pero en una menor medida comparado con el ascenso en los últimos 5 años.

# %%
df.groupby('number_project').mean()
# Out:
#                 satisfaction_level  ...  promotion_last_5years
# number_project                      ...
# 2                         0.478769  ...               0.015494
# 3                         0.687670  ...               0.023428
# 4                         0.695132  ...               0.026804
# 5                         0.678888  ...               0.018109
# 6                         0.273458  ...               0.017036
# 7                         0.118711  ...               0.000000
#
# [6 rows x 7 columns]

# %% [markdown]
# Podría decirse que los proyectos ejecutados podrían mostrar la responsabilidad asignada en la organización. Debe haber un equilibrio: Ni tan poca responsabilidad que parezca que la organización no confía en el empleado, ni tanta que parezca que el empleado es un solo departamento.
#
# Es interesante que aquellos empleados con el mínimo y máximo número de proyectos asignados son los empleados más propensos a abandonar la organización.
#
# Igualmente, los empleados con el mayor número de proyectos realizados no han tenido un ascenso en los últimos 5 años. "Mucha carga, poca recomensa" puede ser un motivo de abandono en esta organización.

# %%
def heatmap_count(df, var1, var2):
  """Generates a Count heatmap of any two columns of a data frame

  Parameters
  ----------
  df : DataFrame
      A DataFrame that has column features
  var1 : str
      The name of a column in the DataFrame
  var2 : str
      The name of a column in the DataFrame. Different from var1
  
  Returns
  -------
  plot : seaborn.heatmap
      A heatmap of the 2 variables grouped by count, with preset configuration
  """

  heat_df=[]
  heat_df=pd.DataFrame(df.groupby([var1,var2]).count().iloc[:,1]).reset_index()
  cols=heat_df.columns
  value=[y for y in cols if y not in [var1, var2]]
  heat_df=heat_df.pivot(columns=var1, index=var2, values=value[0])
  plt.figure(figsize=(15,5))
  return sns.heatmap(heat_df, cmap="Blues",linewidths=0.5, annot=True, fmt='g')

  
heatmap_count(df, "salary_level", "employee_left")

# %% [markdown]
# Se observa que el alto salario parece "prevenir" el abandono en la empresa, dado que al incrementar el nivel de salario, existe un menor porcentaje de personas que abandonan la empresa.

# %%
heatmap_count(df, "department", "employee_left")

# %% [markdown]
# Se logra ver que los departamentos de Sales, support y technical poseen mayor munero de empleados. Además, se ve que existen departamentos como management que tienen una menor tasa de salida (salen 91 de 539+91, vs digamos, en sales que salen 1014 de 1014+3126- que es casi un tercio-)

# %%
heatmap_count(df, "department", "salary_level")

# %% [markdown]
# Los niveles de salario Low y Medium tienen un comportamiento similar entre los departamentos.  Los departamentos Sales, technical y Management son departamentos que presentan un número relativamente mayor de personas de mayor salario.

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eb149c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eb6745f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eb3f4668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eb4c0a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eb4d85c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eb414940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eac6d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eac24780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa2eac247f0>]],
#       dtype=object)

# %%
#Se realiza un mapa de calor de Predictive Power Score (PPS).
#El PPS es una métrica que mide el poder predictivo de una variable sobre otra.
#Esta se utiliza para observar correlaciones y posibles variables de interés para los modelos
matrix_df = pps.matrix(df)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
plt.figure(figsize=(15,5))
sns.heatmap(matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)

# %% [markdown]
# El Predictive Power Score es una medida del poder predictivo de una variable.
#
# Esta gráfica nos muestra que la variable "employee_left" puede ser predecia por las variables "number_projects", y "satisfaction_level", pues la fila de "employee_left" posee valores en estas columnas.
#
# Esta gráfica parece apoyar algunas de las hipótesis que se han ido formando:
# 1. El número de proyectos si tiene poder predictivo sobre la satisfacción del empleado.
# 2. La variable que mayor poder predictivo tiene es la satisfacción del empleado.
# 3. Es posible que los Features más relevantes sean satisfaction_level,number_project, average_monthy_hours, time_spend_company y last_evaluation. Esto son, qeullos features que directamente tienen poder predictivo sobre la variables respuesta; y los features que tienen poder predictivo sobre aquellos que predicen la variable respuesta.

# %% [markdown]
# # Preparación de los datos y Modelado preliminar
# ## Preparación de los datos
# Se aplica cambios a los datos originales, haciendo las variables departmetn y salary_level categóricas.
#
# Se probarán inicialmente los modelos:
#
# * Regresión Logística
# * Random Forest (Clasificador)
# * KNN (Clasificador)
# * Red Neuronal para clasificación binaría
#
# Para las pruebas iniciales, se hará un split 80-20 para Entrenamiento y Prueba, se tomarán más muestras de la clase minoritaria (upsampling) para manejar la clase no balanceada y se tomará la versión "por defecto" de los modelos en sklearn con todos los features del set de datos.
#
# Para comparar los modelos, se usarán la curva ROC-AUC y los datos de la matriz de confusión. Esto es puesto que, al no estar balanceados los datos de las variables respuesta, el acuraccy no es una medida idónea para comparación de modelos.
#
# El objetivo de este paso es la generación de un insight inicial de que tan buenos predictores para el set de datos son cada uno de los modelos.
#
#
# Posteriormente, se hará un tuneo de los hiper parámetros de cada modelo. En este paso, se compará la mejor versión encontrada de cada modelo entre si, y se elegirá aquel que posea una mejor ROC-AUC y Matriz de confusión.

# %%
df=df.astype({"department":"category", "salary_level":"category"})
df.dtypes
# Out:
# satisfaction_level        float64
# last_evaluation           float64
# number_project              int64
# average_montly_hours        int64
# time_spend_company          int64
# Work_accident               int64
# employee_left               int64
# promotion_last_5years       int64
# department               category
# salary_level             category
# dtype: object

# %% [markdown]
# Para la preparación de datos y aplicación de modelos preliminares, se crean funciones personalizadas.

# %%
def get_X_y(df, y_name):
  """
  Splits a DataFrame in X (Features) and y (response variable)
  Parameters
  ----------
  df : DataFrame
      A DataFrame that has column features.
  y_name : str
      The name of the target varriable in the DataFrame.

  Returns
  -------
  X : DataFrame
      DataFrame with the features used to predict y.
  y : Array(int)
      Array with the response variable's values.
  """
  y=[y_name]
  X=[col for col in df.columns if col not in y]
  y=df[y].copy().values.flatten()
  X=pd.get_dummies(df[X].copy())
  return X, y


def data_preprocessing_up_or_down_sample(X, y, sample="up", test_size=0.2):
  """
  Applies downsampling or upsampling, and returns the Train-Test split 
  of data.
  Parameters
  ----------
  X : DataFrame
      DataFrame with the features used to predict y.
  y : Array(int)
      Array with the response variable's values.
  sample : str(optional)
      Chooses the method to apply. Downsampling ("down"), 
      upsampling ("up") or no method (anything else). Default is "up". 
  test_size : float(optional)
      Sets the test_size parameter of sklearn.model_selection.train_test_split.
      Default is 0.2
  
  Returns
  -------
  splitting : list, length=2 * len(arrays)
      List containing train-test split of inputs, with the method defined by
      the parameter sample applied.
  """

  # Use the sample parameter to define local variables to select the correct 
  # method
  a,b=0,0
  if sample=="up": 
    a,b=1,0
  if sample=="down":
    a,b=0,1 

  
  # Apply the normal train_test_split to the data
  X_train, X_test, y_train, y_test = train_test_split( X, y, \
                                        test_size=test_size)
  # Using the a and b local variables, apply downsampling or upsampling only
  # if the sample parameter is "up" or "down".

  if a+b>=1:
    X_train_temp, y_train_temp = resample(X_train[y_train == a],
                                    y_train[y_train == a],
                                    n_samples=X_train[y_train == b].shape[0])
    X_train = np.concatenate((X_train[y_train == b], X_train_temp))
    y_train = np.concatenate((y_train[y_train == b], y_train_temp))
  return (X_train, X_test, y_train, y_test)


def rocauc_plot(model, model_name, y_test, X_test):
  """
  Plots the ROC-AUC curve for a model. 
  Multiple consecutive calls will allow to display multiple curves on the
  same plot

  Parameters
  ----------
  model : estimator object.
      Either from sklearn or keras interfaces
  model_name : str
      Name of the plot
  X_test : {array-like, sparse matrix} of shape (n_samples, n_features)
      Input values
  y_test : {array-like, sparse matrix} of shape (n_samples, n_features)
      Target values
  test_size : float(optional)
      Sets the test_size parameter of sklearn.model_selection.train_test_split.
      Default is 0.2
  
  Returns
  -------
  plot : matplotlib.pyplot
      Plot of the ROC-AUC score
  """
  try:
    auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
  except:
    auc = roc_auc_score(y_test, model.predict(X_test))
    fpr, tpr, thresholds = roc_curve(y_test, model.predict(X_test))
  plt.plot(fpr, tpr, label=model_name+" AUC = {:.5f}".format(auc))
  plt.title("Curva(s) ROC", fontdict={"fontsize": 21})
  plt.xlabel("False positive rate", fontdict={"fontsize": 13})
  plt.ylabel("True positive rate", fontdict={"fontsize": 13})
  plt.legend(loc="lower right")
  plt.plot([0, 1], [0, 1], "r--")



def plot_roc_conf_matrix(y_test,X_test, model, model_name):
  """
  Print the classification report and plots the ROC-AUC curve and confusion 
  matrix for a given model.

  Arguments
  ---------
  y_test : {array-like, sparse matrix} of shape (n_samples, n_features)
      Target values
  X_test : {array-like, sparse matrix} of shape (n_samples, n_features)
      Input values
  model : estimator object.
      Either from sklearn or keras interfaces
  model_name : str
      Name of the model. Used as part of the plot's titles.
  
  """
  try:
    y_pred=model.predict_classes(X_test)
  except:
    y_pred=model.predict(X_test)
  cm = metrics.confusion_matrix(y_test, y_pred)
  plt.figure(figsize=(15,5))
  plt.subplot(1,2,1)
  sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
  plt.title(model_name+ " - Matriz de confusión", y=1.1, \
            fontdict={"fontsize": 21})
  plt.xlabel("Predicted", fontdict={"fontsize": 14})
  plt.ylabel("Actual", fontdict={"fontsize": 14})
 
  print(classification_report(y_test, y_pred))
  plt.subplot(1,2,2)

  rocauc_plot(model, model_name, y_test, X_test)


def apply_model_to_df(data, model, model_name):
  """
  Applies a sklearn estimator to a DataFrame. 
  It returns a fitted model and shows relevant information of the model's
  performance (applies the plot_roc_conf_matrix function to it)

  Parameters
  ----------
  data : List of Arrays
      List of arrays, equivalent to the output of the function
      sklearn.model_selection.train_test_split  
  model : estimator object.
      Either from sklearn or keras interfaces
  model_name : str
      Name of the model. Used as part of the plot's titles.
  
  Returns
  -------
  model : estimator instance
      Fitted classifier or a fitted Pipeline in which the last estimator 
      is a classifier.
  """
  X_train, X_test, y_train, y_test=data
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  plot_roc_conf_matrix(y_test,X_test, model, model_name)
  return model

# %%
# Se separan los datos
X,y=get_X_y(df, "employee_left")
# Se crean conjuntos para probar upsampling, downsampling y sin pre-procesado
data_up = data_preprocessing_up_or_down_sample(X, y ,"up", test_size=0.2)
data_down = data_preprocessing_up_or_down_sample(X, y ,"down", test_size=0.2)
data_as_is= data_preprocessing_up_or_down_sample(X, y ,"None", test_size=0.2)

# %% [markdown]
# ## Modelado preliminar
#
# Aplicando las funciones anteriormente creadas y los modelos propuestos, se realiza un modelado inicial de los datos.
#
# En primer lugar, usando Random Forest, se seleccionará entre:
# * Hacer upsampling (es decir, generar más observaciones de la clase menos ocurrente hasta igualar a la más ocurrente)
# * Hacer dowmsampling (tomar un conjunto más pequeño de la clase más ocurrente, del tamaño de la clase menos ocurrente)
# * No modificar las clases.

# %%
rf_us=apply_model_to_df(data_up,RandomForestClassifier(), "Random Forest - Upsampling")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2262
#            1       0.99      0.96      0.98       738
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.98      0.99      3000
# weighted avg       0.99      0.99      0.99      3000

# %%
rf_ds=apply_model_to_df(data_down,RandomForestClassifier(),"Random Forest - Downsampling")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2273
#            1       0.97      0.97      0.97       727
#
#     accuracy                           0.99      3000
#    macro avg       0.98      0.98      0.98      3000
# weighted avg       0.99      0.99      0.99      3000

# %%
rf_asis=apply_model_to_df(data_as_is,RandomForestClassifier(),"Random Forest - Data As Is")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2281
#            1       1.00      0.96      0.98       719
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.98      0.98      3000
# weighted avg       0.99      0.99      0.99      3000

# %% [markdown]
# Dados estos resultados, se usará upsampling para probar los otros modelos y para futuras pruebas. Se observan los parametros del mejor Random Forest:

# %%
rf_us.get_params(deep=False)
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Y se procede a aplicar diferentes modelos a los datos con el mejor método encontrado:

# %%
lr_no=apply_model_to_df(data_up,LogisticRegression(class_weight="balanced"), "Regresión Logística")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      2262
#            1       0.50      0.80      0.62       738
#
#     accuracy                           0.76      3000
#    macro avg       0.71      0.77      0.72      3000
# weighted avg       0.82      0.76      0.77      3000

# %%
knn_no=apply_model_to_df(data_up,KNeighborsClassifier(), "KNN Classifier")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.94      2262
#            1       0.77      0.96      0.86       738
#
#     accuracy                           0.92      3000
#    macro avg       0.88      0.93      0.90      3000
# weighted avg       0.93      0.92      0.92      3000

# %%
# Se configura la red neuronal usando Keras
# Se usará una red completamente conectada y lo más simple posible, teniendo en
# cuenta el hecho de que es un problema de clasificación binaria.
X_train, X_test, y_train, y_test=data_up
nn=Sequential()
nn.add(Dense(20, input_dim=20, activation='relu'))
nn.add(Dropout(0.15))
nn.add(Dense(1, activation='sigmoid'))
nn.compile(optimizer='adam',loss='binary_crossentropy',\
           metrics=['binary_accuracy'])
nn.fit(X_train,y_train,epochs=10,batch_size=5)
plot_roc_conf_matrix(y_test,X_test, nn, "Red Neuronal Sencilla")
# Out:
# Epoch 1/10
# 3667/3667 [==============================] - 7s 2ms/step - loss: 3.5537 - binary_accuracy: 0.5442
# Epoch 2/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.5840 - binary_accuracy: 0.7138
# Epoch 3/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.4703 - binary_accuracy: 0.8019
# Epoch 4/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.4147 - binary_accuracy: 0.8308
# Epoch 5/10
# 3667/3667 [==============================] - 6s 2ms/step - loss: 0.4104 - binary_accuracy: 0.8398
# Epoch 6/10
# 3667/3667 [==============================] - 6s 2ms/step - loss: 0.4057 - binary_accuracy: 0.8477
# Epoch 7/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.3876 - binary_accuracy: 0.8528
# Epoch 8/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.3858 - binary_accuracy: 0.8618
# Epoch 9/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.3900 - binary_accuracy: 0.8575
# Epoch 10/10
# 3667/3667 [==============================] - 5s 1ms/step - loss: 0.3755 - binary_accuracy: 0.8636
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.89      2262
#            1       0.63      0.95      0.76       738
#
#     accuracy                           0.85      3000
#    macro avg       0.81      0.88      0.83      3000
# weighted avg       0.89      0.85      0.86      3000

# %%
plt.figure(figsize=(10,10))

rocauc_plot(rf_us, "Random Forest", y_test, X_test)
rocauc_plot(knn_no, "KNN", y_test, X_test)
rocauc_plot(nn, "Red Neuronal sencilla", y_test, X_test)
rocauc_plot(lr_no, "Regresión logística", y_test, X_test)

# %% [markdown]
# # Tuneo de Hiper Parámetros y selección de mejor modelo
#
# Para esto, se define un pipeline general para todos los modelos:
#
# 1. Se aplica un StandardScaler, esto es, se estandarizan los datos.
# 2. Se realiza un Grid Search con Cross Validation, usando:
#   1. Una lista de parámetros, con sus posibles valores
#   2. 10-fold Cross Validation
#   3. Selección del mejor modelo por el f1 score.
#
#
# La estandarización de datos se realiza para mejorar el desempeño de los modelos, al ajustar los datos para cumplir los pre-requisitos de los mismos . Dada la naturaleza original no balanceada de los datos, se usa el f1 score y la curva ROC-AUC en lugar del Acuraccy como medida de mejor desempeño.
#
# La principal ventaja del uso de un Pipeline es el hecho de que el pre-procesado puede incluirse en la misma para poder usar el modelo en un dataset sin pre-procesado aplicado. El resultado de la combinación de un Pipeline+GridSearchCV genera un objeto de Pipeline que, al usar el métor
#
# El mejor modelo entonces se guarda, y se simula su carga y evaluación sobre datos nunca vistos (con los datos de prueba).

# %%
X,y=get_X_y(df, "employee_left")
X_train, X_test, y_train, y_test =data_preprocessing_up_or_down_sample(X, y , "up",test_size=0.2)

# %%
def pipeline_classifier(X,y,model, param_grid):
  """
  Creates a general Pipeline for sklearn classifiers.
  Applies GridSearchCV to optimize hyper parameters of the model.

  Parameters
  ----------
  X : {array-like, sparse matrix} of shape (n_samples, n_features)
      Input values
  y : {array-like, sparse matrix} of shape (n_samples)
      Target values
  model : sklearn.estimator object
      Instance of an estimator form sklearn.
  param_grid: dict or list of dictionaries
      Dictionary with parameters names (str) as keys and lists of parameter 
      settings to try as values, or a list of such dictionaries, in which case 
      the grids spanned by each dictionary in the list are explored. 
      This enables searching over any sequence of parameter settings.
    
  Returns
  -------
  model : sklearn.estimator instance
      Fitted classifier or a fitted Pipeline in which the last estimator 
      is a classifier.
  """
  pipe = make_pipeline(StandardScaler(), model)
  clf= GridSearchCV(pipe,
                    param_grid=param_grid,
                    cv=10,
                    refit=True,
                    scoring="f1",
                    n_jobs=-1)
  clf.fit(X,y)
  return clf

# %%
rf_param_grid = {
        "randomforestclassifier__min_samples_leaf": [1, 3, 5],
        "randomforestclassifier__n_estimators": [50,100, 250],
        "randomforestclassifier__criterion": ["gini", "entropy"]}
rf_gs=pipeline_classifier(X_train,y_train,
                          RandomForestClassifier(class_weight="balanced")\
                          ,rf_param_grid )

# %%
rf_gs.best_params_
# Out:
# {'randomforestclassifier__criterion': 'entropy',
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__n_estimators': 250}

# %%
plot_roc_conf_matrix(y_test,X_test, rf_gs, "Random Forest (GS)")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2261
#            1       0.99      0.97      0.98       739
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.98      0.99      3000
# weighted avg       0.99      0.99      0.99      3000

# %%
lr_param_grid = {"logisticregression__penalty": ["l1", "l2"],
                   "logisticregression__C":  np.arange(0.5, 20, 0.5),
                   "logisticregression__fit_intercept": [True, False]
                  }
lr_gs=pipeline_classifier(X_train,y_train,
                         LogisticRegression(class_weight="balanced"), lr_param_grid )

# %%
lr_gs.best_params_
# Out:
# {'logisticregression__C': 0.5,
#  'logisticregression__fit_intercept': False,
#  'logisticregression__penalty': 'l2'}

# %%
plot_roc_conf_matrix(y_test,X_test, lr_gs, "Regresión Logística (GS)")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82      2261
#            1       0.51      0.82      0.63       739
#
#     accuracy                           0.76      3000
#    macro avg       0.72      0.78      0.72      3000
# weighted avg       0.82      0.76      0.77      3000

# %%
knn_param_grid = {"kneighborsclassifier__n_neighbors": range(1, 20),
                  "kneighborsclassifier__weights": ["uniform", "distance"]}
knn_gs=pipeline_classifier(X_train,y_train,
                         KNeighborsClassifier(), knn_param_grid )

# %%
knn_gs.best_params_
# Out:
# {'kneighborsclassifier__n_neighbors': 1,
#  'kneighborsclassifier__weights': 'uniform'}

# %%
plot_roc_conf_matrix(y_test,X_test, knn_gs, "KNN (GS)")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      2261
#            1       0.93      0.95      0.94       739
#
#     accuracy                           0.97      3000
#    macro avg       0.95      0.96      0.96      3000
# weighted avg       0.97      0.97      0.97      3000

# %%
# Dado el funcionamiento de GridSearch, es necesario el uso de un wrapper para
# usarlo con una red neuronal. Para ello, hay que definir una funcion y crear
# una instancia de un KeraClassifier.
# Esto permite tratar a la red neuronal como un sklearn.estimator, y por tanto,
# su uso con GridSearchCV
def nn_base_model():
  """
  A basic wrapper function to use Keras NN on GridSearchCV.
   
  Returns
  -------
  nn : wrapped keras.Sequential model 
      A Keras basic Neural Network for Binary classification, wrapped for usage
      in KerasClassifier() build_fn parameter.
      
  """
  nn=Sequential()
  nn.add(Dense(20, input_dim=20, activation='relu'))
  nn.add(Dropout(0.15))
  nn.add(Dense(1, activation='sigmoid'))
  nn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['binary_accuracy'])
  return nn
nn_base=KerasClassifier(build_fn=nn_base_model, verbose='None')

# %%
nn_param_grid = {"kerasclassifier__epochs": [5,10,15],
                 "kerasclassifier__batch_size": [5, 10,20]}
nn_gs=pipeline_classifier(X_train,y_train,
                         nn_base, nn_param_grid )
# Out:
# Epoch 1/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.4651 - binary_accuracy: 0.7740
# Epoch 2/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.2296 - binary_accuracy: 0.9193
# Epoch 3/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.2082 - binary_accuracy: 0.9295
# Epoch 4/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.2121 - binary_accuracy: 0.9228
# Epoch 5/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.2059 - binary_accuracy: 0.9294
# Epoch 6/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.2027 - binary_accuracy: 0.9314
# Epoch 7/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.1962 - binary_accuracy: 0.9311
# Epoch 8/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.1975 - binary_accuracy: 0.9303
# Epoch 9/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.1915 - binary_accuracy: 0.9352
# Epoch 10/10
# 3662/3662 [==============================] - 4s 1ms/step - loss: 0.1980 - binary_accuracy: 0.9335

# %%
nn_gs.best_params_
# Out:
# {'kerasclassifier__batch_size': 5, 'kerasclassifier__epochs': 10}

# %%
plot_roc_conf_matrix(y_test,X_test, nn_gs, "NN (GS)")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      2275
#            1       0.84      0.92      0.88       725
#
#     accuracy                           0.94      3000
#    macro avg       0.90      0.93      0.92      3000
# weighted avg       0.94      0.94      0.94      3000

# %%
plt.figure(figsize=(10,10))


rocauc_plot(rf_gs, "Random Forest", y_test, X_test)
rocauc_plot(knn_gs, "KNN", y_test, X_test)
rocauc_plot(lr_gs, "Regresión logística", y_test, X_test)
rocauc_plot(nn_gs, "Red Neuronal Simple", y_test, X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-04e6832b1271> in <module>()
#       5 rocauc_plot(knn_gs, "KNN", y_test, X_test)
#       6 rocauc_plot(lr_gs, "Regresión logística", y_test, X_test)
# ----> 7 rocauc_plot(nn_gs, "Red Neuronal Simple", y_test, X_test)
#
# NameError: name 'nn_gs' is not defined

# %% [markdown]
# El mejor modelo es el Random Forest. Se procede a guardar el modelo y se simula la carga del mismo y su uso para predecir la probablidad de que un empleado abanode la organización sobre datos "reales" o no vistos (esto es, el set de pruebas que se separó antes de entrenar a los modelos)

# %%
# Se crea una copia de la clase de nuestro pipeline de predicción
model_to_save=rf_gs
# Se agrega el atributo feature_names_
# Este es, un array con los nombres de los features
model_to_save.feature_names_=X.columns.values
# Se agrega el atributo feature_df_.
# Este es, un DataFrame con los Feature y su importancia en el modelo
imp_df=pd.DataFrame(X.T.iloc[:,1])
imp_df[1]=rf_gs.best_estimator_[1].feature_importances_
imp_df=imp_df.rename(columns = {1:'Feature Importance'})\
             .sort_values(by='Feature Importance', ascending=False)\
             .reset_index().rename(columns = {'index':'Feature'})
model_to_save.feature_df_=imp_df

# %%
# Se guarda el modelo
joblib.dump(model_to_save, 'Grid_Search_rf.pkl')
# Out:
# ['Grid_Search_rf.pkl']

# %%
# Se carga el modelo
clonk_model=joblib.load("Grid_Search_rf.pkl")

# %%
"""
Usando el atributo creado, feature_df_, se genera un gráfico de Feature
Importance del modelo.
"""
plt.figure(figsize=(15, 5))
plt.bar(clonk_model.feature_df_['Feature'], \
        clonk_model.feature_df_['Feature Importance'])
_=plt.xticks( rotation=90)
plt.title("Feature Importance [Modelo Preliminar]");

# %%
# !pip install shap
import shap
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/44/20/54381999efe3000f70a7f68af79ba857cfa3f82278ab0e02e6ba1c06b002/shap-0.38.1.tar.gz (352kB)
#      |████████████████████████████████| 358kB 4.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from shap) (0.22.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.6/dist-packages (from shap) (4.41.1)
# Collecting slicer==0.0.7
#   Downloading https://files.pythonhosted.org/packages/78/c2/b3f55dfdb8af9812fdb9baf70cacf3b9e82e505b2bd4324d588888b81202/slicer-0.0.7-py3-none-any.whl
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->shap) (1.0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.6/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->shap) (51.3.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.38.1-cp36-cp36m-linux_x86_64.whl size=489403 sha256=82c0daa89151574b5f1181a975ac2a300313c6f3f51417c212de1daf67d09c5a
#   Stored in directory: /root/.cache/pip/wheels/a8/fb/e4/88012be41842b9be62ae18d82d1b1e880daf8539d1fef1fa00
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.38.1 slicer-0.0.7

# %%
print("h")

# %%
"""
Usando los datos a los que no ha sido expuesto el modelo, y_test y X_test
para simular la exposición a datos a datos nunca vistos.

Se crea un dataframe a partir de estos y realizaremos la predicción
del modelo sobre estos datos y evaluaremos la calidad del modelo.

"""
model_test=X_test.copy()
model_test["employee_left (Real)"]=y_test
model_test["employee_left (Predicted_probability)"]=\
            clonk_model.predict_proba(model_test.iloc[:,:-1])[:,1]
model_test["employee_left (Predicted)"]=\
            clonk_model.predict(model_test.iloc[:,:-2])
model_test.reset_index(inplace=True)
model_test
# Out:
#       index  ...  employee_left (Predicted)
# 0     14805  ...                          1
# 1       968  ...                          1
# 2      4917  ...                          0
# 3      8329  ...                          0
# 4     10095  ...                          0
# ...     ...  ...                        ...
# 2995   8587  ...                          0
# 2996  13109  ...                          0
# 2997  13281  ...                          0
# 2998   8425  ...                          0
# 2999  13559  ...                          0
#
# [3000 rows x 24 columns]

# %%
# Se simula la evaluación del modelo sobre datos nunca vistos.
plot_roc_conf_matrix(y_test,X_test, clonk_model, "Modelo Preliminar - Prueba")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2261
#            1       0.99      0.97      0.98       739
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.98      0.99      3000
# weighted avg       0.99      0.99      0.99      3000
